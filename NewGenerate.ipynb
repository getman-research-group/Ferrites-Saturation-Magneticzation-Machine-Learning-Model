# %%
import math
import os
import re
import pandas as pd
import numpy
from sklearn import preprocessing

redox = [0.44, 0.28, 0.25, 0.76, -0.34, 1.18]# Me - 2e = Me2+ http://accounts.smccd.edu/batesa/chem220/reference/Reduction-Potential.PDF
elenega = [1.83, 1.88, 1.91, 1.65, 1.90, 1.55]
eleaff = [16.7, 64.7, 113, 1, 119.4, 1]
valence = [3, 4, 2, 2, 2, 4]
ioni1 = [762.5, 760.4, 737.1, 906.4, 745.5, 717.3]
ioni2 = [1561.876, 1648.356, 1753.027, 1733.3, 1957.919, 717.3]
ioni3 = [2957, 3232, 3395, 3833, 3555, 3248]
ioni4 = [5290, 4950, 5300, 5731, 5536, 4940]
ioni5 = [7240, 7670, 7339, 7970, 7700, 6990]
radius = [156, 152, 149, 142, 145, 161]
EC = [100, 170, 140, 170, 590, 6.2]#electronic conductivity
NC = [2.56, 37.2, 4.5, 1.1, 3.78, 13.3] #Neutron Cross Section
NM = [0.0015, 0.0021, 0.0026, 0.00055, 0.0021, 0.0083] #	Neutron Mass Absorption	
LCx =[286.65, 250.71, 352.4, 266.49, 361.49, 891.25] #lattice constants_x
LCz =[286.65, 406.95, 352.4, 494.68, 361.49, 891.25] #lattice constants_z
SH = [449.0, 421.0, 445.0, 388.0, 384.4, 479.0] #specific HEAT
iradius = [75, 79, 83, 88, 87, 81] #ionic radius https://www.webelements.com
hyden = [-1840, -1915, -1980, -1915, -2010, -1760]#hydrogenation energy https://pubs.rsc.org/en/content/articlepdf/1991/ft/ft9918702995
oxir = [-648, -513, -360, -694, -368, -772 ]# Me + 0.5O2 = MeO 
TC = [79, 100, 91, 120, 400,7.7] #THERMAL Conductivity
HF = [13.8, 16.2, 17.2, 7.35, 13.1, 13.2] #heat of fusion
resis = [9.7,6,7,5.9,1.7, 160] #resistivit

# %%
redox = preprocessing.scale(redox)
elenega = preprocessing.scale(elenega)
eleaff = preprocessing.scale(eleaff)
valence = preprocessing.scale(valence)
ioni1 = preprocessing.scale(ioni1)
ioni2 = preprocessing.scale(ioni2)
ioni3 = preprocessing.scale(ioni3)
ioni4 = preprocessing.scale(ioni4)
ioni5 = preprocessing.scale(ioni5)
radius = preprocessing.scale(radius)
EC = preprocessing.scale(EC)
NC = preprocessing.scale(NC)
NM = preprocessing.scale(NM)
LCx = preprocessing.scale(LCx)
LCz = preprocessing.scale(LCz)
SH = preprocessing.scale(SH)
iradius = preprocessing.scale(iradius)
hyden = preprocessing.scale(hyden)
oxir = preprocessing.scale(oxir)
TC = preprocessing.scale(TC)
HF = preprocessing.scale(HF)
resis = preprocessing.scale(resis)

# %%
import math
import os
import re
import pandas as pd
import numpy
from sklearn import preprocessing



featuretotal = []
test=[]
df = pd.read_csv('Fe_Ni_new.csv')  # doctest: +SKIP
#print(df)
total=[]
for i in range(70):
    total.append(numpy.array(df.loc[i]))
print(len(total))
for list_metals in total:
        preass_x = [0.25, 0.75, 0.75, 0.25, 0.0, 0.5, 0.5, 0]
        preass_y = [0.25, 0.75, 0.5, 0.5, 0.5, 0.25, 0.75, 1.0]
        preass_z =[0.5, 0.5, 0.75, 0.25, 0.0, 0.25, 0.75, 0.5]
        metals = ['Fe', 'Co', 'Ni', 'Zn', 'Cu', 'Mn']
        elenega_m = [0, 0, 0, 0, 0, 0, 0, 0]#preassign the 8 sites interested
        eleaff_m =[0, 0, 0, 0, 0, 0, 0, 0]
        valence_m =[0, 0, 0, 0, 0, 0, 0, 0]
        ioni1_m =[0, 0, 0, 0, 0, 0, 0, 0]
        ioni2_m = [0, 0, 0, 0, 0, 0, 0, 0]
        ioni3_m = [0, 0, 0, 0, 0, 0, 0, 0]
        ioni4_m = [0, 0, 0, 0, 0, 0, 0, 0]
        ioni5_m = [0, 0, 0, 0, 0, 0, 0, 0]
        EC_m = [0, 0, 0, 0, 0, 0, 0, 0]
        NC_m = [0, 0, 0, 0, 0, 0, 0, 0]
        NM_m = [0, 0, 0, 0, 0, 0, 0, 0]
        LCx_m = [0, 0, 0, 0, 0, 0, 0, 0]
        LCz_m = [0, 0, 0, 0, 0, 0, 0, 0]
        SH_m = [0, 0, 0, 0, 0, 0, 0, 0]
        radius_m = [0, 0, 0, 0, 0, 0, 0, 0]
        iradius_m = [0, 0, 0, 0, 0, 0, 0, 0]
        oxir_m = [0, 0, 0, 0, 0, 0, 0, 0]
        hyden_m = [0, 0, 0, 0, 0, 0, 0, 0]
        TC_m = [0, 0, 0, 0, 0, 0, 0, 0]
        HF_m = [0, 0, 0, 0, 0, 0, 0, 0]
        resis_m = [0, 0, 0, 0, 0, 0, 0, 0]
        redox_m = [0, 0, 0, 0, 0, 0, 0, 0]
        nn = 0
        for i in range(8):
            for n in range(6):
                 if list_metals[i] == metals[n]:
                    elenega_m[i] = elenega[n] # assign the value corresponding the metal atoms
                    eleaff_m[i] = eleaff[n]
                    valence_m[i] = valence[n]
                    ioni1_m[i] = ioni1[n]
                    ioni2_m[i] = ioni2[n]
                    ioni3_m[i] = ioni3[n]
                    ioni4_m[i] = ioni4[n]
                    ioni5_m[i] = ioni5[n]
                    EC_m[i] = EC[n]
                    NC_m[i] = NC[n]
                    NM_m[i] = NM[n]
                    LCx_m[i] = LCx[n]
                    LCz_m[i] = LCz[n]
                    SH_m[i] = SH[n]
                    radius_m[i] = radius[n]
                    iradius_m[i] = iradius[n]
                    oxir_m[i] = oxir[n]
                    hyden_m[i] = hyden[n]
                    TC_m[i] = TC[n]
                    HF_m[i] = HF[nn]
                    resis_m[i] = resis[n]
                    redox_m[i] = redox[n]
        elenegaf = [0, 0, 0, 0, 0, 0, 0, 0]
        eleafff = [0, 0, 0, 0, 0, 0, 0, 0]
        valencef = [0, 0, 0, 0, 0, 0, 0, 0]
        ioni1f = [0, 0, 0, 0, 0, 0, 0, 0]
        ioni2f = [0, 0, 0, 0, 0, 0, 0, 0]
        ioni3f = [0, 0, 0, 0, 0, 0, 0, 0]
        ioni4f = [0, 0, 0, 0, 0, 0, 0, 0]
        ioni5f = [0, 0, 0, 0, 0, 0, 0, 0]
        ECf = [0, 0, 0, 0, 0, 0, 0, 0]  
        NCf = [0, 0, 0, 0, 0, 0, 0, 0]  
        NMf = [0, 0, 0, 0, 0, 0, 0, 0]  
        SHf = [0, 0, 0, 0, 0, 0, 0, 0]  
        LCxf = [0, 0, 0, 0, 0, 0, 0, 0]  
        LCzf = [0, 0, 0, 0, 0, 0, 0, 0]  
        radiusf = [0, 0, 0, 0, 0, 0, 0, 0]
        TCf = [0, 0, 0, 0, 0, 0, 0, 0]
        HFf = [0, 0, 0, 0, 0, 0, 0, 0]
        resisf = [0, 0, 0, 0, 0, 0, 0, 0]
        redoxf = [0, 0, 0, 0, 0, 0, 0, 0]
        iradiusf = [0, 0, 0, 0, 0, 0, 0, 0]
        oxirf = [0, 0, 0, 0, 0, 0, 0, 0]
        hydenf = [0, 0, 0, 0, 0, 0, 0, 0]
        for p in range(8):
            elenega_ac = 0
            eleaff_ac = 0
            valence_ac = 0
            ioni1_ac = 0
            ioni2_ac = 0
            ioni3_ac = 0
            ioni4_ac = 0
            ioni5_ac = 0
            EC_ac = 0
            NC_ac = 0
            NM_ac = 0
            SH_ac = 0
            LCx_ac = 0
            LCz_ac = 0
            radius_ac = 0
            TC_ac = 0
            HF_ac = 0
            iradius_ac = 0
            oxir_ac = 0
            hyden_ac = 0
            resis_ac = 0
            redox_ac = 0
            for q in range(8):
#                ss = 16 + int(p)
                if q!= p:
                    elenega_ac = elenega_ac + elenega_m[p]*elenega_m[q] / math.sqrt(1 + 
                            abs(preass_x[p]**2 - preass_x[q]**2) +abs(preass_y[p]**2 - preass_y[q]**2) + abs(preass_z[p]**2 - preass_z[q]**2))
                    eleaff_ac = eleaff_ac + eleaff_m[p]* eleaff_m[q] /  math.sqrt(1 + 
                            abs(preass_x[p]**2 - preass_x[q]**2) +abs(preass_y[p]**2 - preass_y[q]**2) + abs(preass_z[p]**2 - preass_z[q]**2))
                    valence_ac = valence_ac + valence_m[p] * valence_m[q] /  math.sqrt(1 + abs(preass_x[p]**2 - preass_x[q]**2) +abs(preass_y[p]**2 - preass_y[q]**2) + abs(preass_z[p]**2 - preass_z[q]**2))
                    ioni1_ac = ioni1_ac + ioni1_m[p] * ioni1_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p]** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 -preass_z[q] ** 2))
                    ioni2_ac = ioni2_ac + ioni2_m[p] * ioni2_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    ioni3_ac = ioni3_ac + ioni3_m[p] * ioni3_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    ioni4_ac = ioni4_ac + ioni4_m[p] * ioni4_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    ioni5_ac = ioni5_ac + ioni5_m[p] * ioni5_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    EC_ac = EC_ac + EC_m[p] * EC_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    NC_ac = NC_ac + NC_m[p] * NC_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    NM_ac = NM_ac + NM_m[p] * NM_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    SH_ac = SH_ac + SH_m[p] * SH_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    LCx_ac = LCx_ac + LCx_m[p] * LCx_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    LCz_ac = LCz_ac + LCz_m[p] * LCz_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    radius_ac = radius_ac + radius_m[p] * radius_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    TC_ac = TC_ac + TC_m[p] * TC_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    HF_ac = HF_ac + HF_m[p] * HF_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    resis_ac = resis_ac + resis_m[p] * resis_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    redox_ac = redox_ac + redox_m[p] * redox_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    iradius_ac = iradius_ac + iradius_m[p] * iradius_m[q] / math.sqrt(1 + 
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    oxir_ac = oxir_ac + oxir_m[p] * oxir_m[q] / math.sqrt(1 +
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
                    hyden_ac = hyden_ac + hyden_m[p] * hyden_m[q] / math.sqrt(1 + 
                            abs(preass_x[p] ** 2 - preass_x[q] ** 2) + abs(preass_y[p] ** 2 - preass_y[q] ** 2) + abs(preass_z[p] ** 2 - preass_z[q] ** 2))
            elenega_av = elenega_ac / 7
            eleaff_av = eleaff_ac / 7
            valence_av = valence_ac / 7
            ioni1_av = ioni1_ac / 7
            ioni2_av = ioni2_ac / 7
            ioni3_av = ioni3_ac / 7
            ioni4_av = ioni4_ac / 7
            ioni5_av = ioni5_ac / 7
            EC_av = EC_ac/7 
            NC_av = NC_ac/7 
            NM_av = NM_ac/7 
            SH_av = SH_ac/7 
            LCx_av = LCx_ac/7
            LCz_av = LCz_ac/7
            radius_av = radius_ac / 7
            TC_av = TC_ac / 7
            iradius_av = iradius_ac / 7
            oxir_av = oxir_ac / 7
            hyden_av = hyden_ac / 7
            HF_av = HF_ac / 7
            resis_av = resis_ac / 7
            redox_av = redox_ac / 7
            elenegaf[p] = elenega_av
            eleafff[p] = eleaff_av
            valencef[p] = valence_av
            ioni1f[p] = ioni1_av
            ioni2f[p] = ioni2_av
            ioni3f[p] = ioni3_av
            ioni4f[p] = ioni4_av
            ioni5f[p] = ioni5_av
            ECf[p] = EC_av 
            NCf[p] = NC_av
            NMf[p] = NM_av
            SHf[p] = SH_av
            LCxf[p] = LCx_av
            LCzf[p] = LCz_av
            radiusf[p] = radius_av
            TCf[p] = TC_av
            iradiusf[p] = iradius_av
            oxirf[p] = oxir_av
            hydenf[p] = hyden_av
            HFf[p] = HF_av
            resisf[p] = resis_av
            redoxf[p] = redox_av
            
        
        feature = elenegaf + eleafff + valencef + ioni1f + ioni2f + radiusf + redoxf + TCf + HFf + resisf + iradiusf + oxirf + hydenf + ioni3f + ioni4f + ioni5f + ECf + NCf + NMf + SHf + LCxf + LCzf
        #print(feature)
        featuretotal.append(feature)
# Out:
# 70

# %%
print(len(featuretotal))
# Out:
# 70

# %%
with open("Fe_Ni_feature_new.txt", 'a') as file:
            for item in featuretotal:
                file.write("%s " % item) 
                file.write('\n')

# %%
        preass_x =[0.125, 0.875, 0.625, 0.375, 0.125, 0.875, 0.625, 0.375, 0.5, 0.25, 0.75, 0.75, 0.25, 1.0, 0.0, 0.5, 0.25,
                   0.75, 0.75, 0.25, 0.0, 0.5, 0.5, 0.0]
